# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('webtraffic.csv')

# %%
data.shape
# Out:
# (4896, 2)

# %%
data.head()
# Out:
#    Hour Index    Sessions
# 0           0  1418159421
# 1           1  1113769116
# 2           2   919158921
# 3           3   822352824
# 4           4   735526737

# %% [markdown]
# # Data Exploration for Web Traffic Forecasting

# %%
import matplotlib.pyplot as plt
sessions = data['Sessions'].values

# %%
ar = np.arange(len(sessions))
plt.figure(figsize=(22,10))
plt.plot(ar, sessions,'r')
plt.show()

# %%
#Let’s explore this data, at a more granular level, and replacing the entire time series, with a subset of it.

#first week web traffic
sample = sessions[:168]
ar = np.arange(len(sample))
plt.figure(figsize=(22,10))
plt.plot(ar, sample,'r')
plt.show()

# %% [markdown]
# # Data Preparation for Web Traffic Forecasting

# %%
#let’s prepare the data for model training, here I have created input sequences, from the block traffic data.

def prepare_data(seq,num):
  x=[]
  y=[]
  for i in range(0,(len(seq)-num),1):
    
    input_ = seq[i:i+num]
    output  = seq[i+num]
    
    x.append(input_)
    y.append(output)
    
  return np.array(x), np.array(y)

# %%
#I have specified the sequence length of one week or 168 hours

num=168
x,y= prepare_data(sessions,num)
print(len(x))
# Out:
# 4728

# %% [markdown]
# # Splitting the Dataset

# %%
#Next, I have split the data into a training set and validation set in the ratio, 90 is to 10. Now that sense it is a time serious problem, I have not splitted the data randomly, but in a sequential manner.

ind = int(0.9 * len(x))
x_tr = x[:ind]
y_tr = y[:ind]
x_val=x[ind:]
y_val=y[ind:]

# %%
#I have scaled the data, both the input sequences and the target values, are scaled

from sklearn.preprocessing import StandardScaler
#normalizing the inputs
x_scaler= StandardScaler()
x_tr = x_scaler.fit_transform(x_tr)
x_val= x_scaler.transform(x_val)

# %%
#reshaping the output for normalization
y_tr=y_tr.reshape(len(y_tr),1)
y_val=y_val.reshape(len(y_val),1)

# %%
#normalizing the output
y_scaler=StandardScaler()
y_tr = y_scaler.fit_transform(y_tr)[:,0]
y_val = y_scaler.transform(y_val)[:,0]

# %%
#I have reshaped the data from two dimensional to 3 dimensional because LSTM only accepts 3 dimensional data.

#reshaping input data
x_tr= x_tr.reshape(x_tr.shape[0],x_tr.shape[1],1)
x_val= x_val.reshape(x_val.shape[0],x_val.shape[1],1)
print(x_tr.shape)
# Out:
# (4255, 168, 1)

# %% [markdown]
# So third dimension is the length of the vectors of the sequence elements.

# %% [markdown]
# # Model Building for Web Traffic Forecasting

# %%
from keras.models import *
from keras.layers import *
from keras.callbacks import *
from tensorflow import keras

# %%
# define model
model =  Sequential()
model.add(LSTM(128,input_shape=(168,1)))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 74,881
# Trainable params: 74,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define the optimizer and loss
model.compile(loss='mse',optimizer='adam')

# %%
#Define the callback to save the best model during the training
mc = ModelCheckpoint('best_model.hdf5', monitor='val_loss',verbose=1, save_best_only=True, mode='min')

# %%
# Train the model for 30 epochs with batch size of 32:
history=model.fit(x_tr, y_tr ,epochs=30, batch_size=32, validation_data=(x_val,y_val), callbacks=[mc])
# Out:
# Epoch 1/30
# 133/133 [==============================] - ETA: 0s - loss: 0.1583
# Epoch 1: val_loss improved from inf to 0.03969, saving model to best_model.hdf5
# 133/133 [==============================] - 37s 234ms/step - loss: 0.1583 - val_loss: 0.0397
# Epoch 2/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0433
# Epoch 2: val_loss improved from 0.03969 to 0.02757, saving model to best_model.hdf5
# 133/133 [==============================] - 28s 214ms/step - loss: 0.0433 - val_loss: 0.0276
# Epoch 3/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0356
# Epoch 3: val_loss did not improve from 0.02757
# 133/133 [==============================] - 28s 212ms/step - loss: 0.0356 - val_loss: 0.0282
# Epoch 4/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 4: val_loss did not improve from 0.02757
# 133/133 [==============================] - 29s 215ms/step - loss: 0.0314 - val_loss: 0.0408
# Epoch 5/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0315
# Epoch 5: val_loss improved from 0.02757 to 0.02338, saving model to best_model.hdf5
# 133/133 [==============================] - 27s 207ms/step - loss: 0.0315 - val_loss: 0.0234
# Epoch 6/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0312
# Epoch 6: val_loss did not improve from 0.02338
# 133/133 [==============================] - 28s 209ms/step - loss: 0.0312 - val_loss: 0.0242
# Epoch 7/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 7: val_loss did not improve from 0.02338
# 133/133 [==============================] - 28s 210ms/step - loss: 0.0307 - val_loss: 0.0244
# Epoch 8/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 8: val_loss did not improve from 0.02338
# 133/133 [==============================] - 30s 222ms/step - loss: 0.0279 - val_loss: 0.0272
# Epoch 9/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 9: val_loss did not improve from 0.02338
# 133/133 [==============================] - 30s 226ms/step - loss: 0.0277 - val_loss: 0.0295
# Epoch 10/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 10: val_loss improved from 0.02338 to 0.02315, saving model to best_model.hdf5
# 133/133 [==============================] - 28s 209ms/step - loss: 0.0270 - val_loss: 0.0232
# Epoch 11/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0252
# Epoch 11: val_loss did not improve from 0.02315
# 133/133 [==============================] - 27s 207ms/step - loss: 0.0252 - val_loss: 0.0236
# Epoch 12/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 12: val_loss improved from 0.02315 to 0.01896, saving model to best_model.hdf5
# 133/133 [==============================] - 27s 207ms/step - loss: 0.0225 - val_loss: 0.0190
# Epoch 13/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 13: val_loss improved from 0.01896 to 0.01849, saving model to best_model.hdf5
# 133/133 [==============================] - 28s 208ms/step - loss: 0.0210 - val_loss: 0.0185
# Epoch 14/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 14: val_loss did not improve from 0.01849
# 133/133 [==============================] - 28s 210ms/step - loss: 0.0213 - val_loss: 0.0290
# Epoch 15/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0201
# Epoch 15: val_loss did not improve from 0.01849
# 133/133 [==============================] - 29s 220ms/step - loss: 0.0201 - val_loss: 0.0221
# Epoch 16/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0205
# Epoch 16: val_loss did not improve from 0.01849
# 133/133 [==============================] - 28s 209ms/step - loss: 0.0205 - val_loss: 0.0212
# Epoch 17/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 17: val_loss improved from 0.01849 to 0.01821, saving model to best_model.hdf5
# 133/133 [==============================] - 28s 212ms/step - loss: 0.0179 - val_loss: 0.0182
# Epoch 18/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0172
# Epoch 18: val_loss did not improve from 0.01821
# 133/133 [==============================] - 29s 215ms/step - loss: 0.0172 - val_loss: 0.0223
# Epoch 19/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0176
# Epoch 19: val_loss did not improve from 0.01821
# 133/133 [==============================] - 27s 206ms/step - loss: 0.0176 - val_loss: 0.0183
# Epoch 20/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 20: val_loss did not improve from 0.01821
# 133/133 [==============================] - 27s 206ms/step - loss: 0.0170 - val_loss: 0.0200
# Epoch 21/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0173
# Epoch 21: val_loss did not improve from 0.01821
# 133/133 [==============================] - 29s 215ms/step - loss: 0.0173 - val_loss: 0.0200
# Epoch 22/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 22: val_loss did not improve from 0.01821
# 133/133 [==============================] - 28s 208ms/step - loss: 0.0167 - val_loss: 0.0196
# Epoch 23/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 23: val_loss improved from 0.01821 to 0.01550, saving model to best_model.hdf5
# 133/133 [==============================] - 28s 208ms/step - loss: 0.0162 - val_loss: 0.0155
# Epoch 24/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 24: val_loss did not improve from 0.01550
# 133/133 [==============================] - 28s 209ms/step - loss: 0.0155 - val_loss: 0.0157
# Epoch 25/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 25: val_loss did not improve from 0.01550
# 133/133 [==============================] - 27s 205ms/step - loss: 0.0161 - val_loss: 0.0165
# Epoch 26/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 26: val_loss did not improve from 0.01550
# 133/133 [==============================] - 27s 205ms/step - loss: 0.0163 - val_loss: 0.0199
# Epoch 27/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 27: val_loss did not improve from 0.01550
# 133/133 [==============================] - 30s 223ms/step - loss: 0.0155 - val_loss: 0.0207
# Epoch 28/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0154
# Epoch 28: val_loss did not improve from 0.01550
# 133/133 [==============================] - 28s 212ms/step - loss: 0.0154 - val_loss: 0.0168
# Epoch 29/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 29: val_loss did not improve from 0.01550
# 133/133 [==============================] - 28s 208ms/step - loss: 0.0157 - val_loss: 0.0168
# Epoch 30/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 30: val_loss did not improve from 0.01550
# 133/133 [==============================] - 28s 210ms/step - loss: 0.0155 - val_loss: 0.0187

# %%
model.load_weights('best_model.hdf5')

# %%
#moving on to the evaluation part 
mse = model.evaluate(x_val,y_val)
print("Mean Square Error:",mse)
# Out:
# 15/15 [==============================] - 2s 115ms/step - loss: 0.0155
# Mean Square Error: 0.015499645844101906

# %% [markdown]
# # Baseline Model with Forecasting

# %%
# building a simple moving average model
def compute_moving_average(data):
  pred=[]
  for i in data:
    avg=np.sum(i)/len(i)
    pred.append(avg)
  return np.array(pred)

# %%
# reshaping the data
x_reshaped = x_val.reshape(-1,168)

# %%
# get predictions
y_pred = compute_moving_average(x_reshaped)

# %%
# evaluating the performance of model on the validation data
mse = np.sum ( (y_val - y_pred) **2 ) / (len(y_val))
print("Mean square of error:- ",mse)
# Out:
# Mean square of error:-  0.5546025834434455

# %% [markdown]
# On the same validation data, I got a score of 0.554 which is way higher than this previous error.So the LSTM based model has done exceptionally well as compared to the baseline model

# %% [markdown]
# # Web Traffic Forecasting

# %%
def forecast(x_val, no_of_pred, ind):
  predictions=[]
  #intialize the array with a weeks data
  temp=x_val[ind]
  for i in range(no_of_pred):
    #predict for the next hour
    pred=model.predict(temp.reshape(1,-1,1))[0][0]
    
    #append the prediction as the last element of array
    temp = np.insert(temp,len(temp),pred)
    predictions.append(pred)
    #ignore the first element of array
    temp = temp[1:]
  return predictions

# %%
#It’s time to forecast the traffic for the next 24 hours based on the previous week data.

no_of_pred =24
ind=72
y_pred= forecast(x_val,no_of_pred,ind)
y_true = y_val[ind:ind+(no_of_pred)]
# Out:
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
#Now plotting of real vs forecast values.

def plot(y_true,y_pred):
  ar = np.arange(len(y_true))
  plt.figure(figsize=(22,10))
  plt.plot(ar, y_true,'r')
  plt.plot(ar, y_pred,'y')
  plt.show()
plot(y_true,y_pred)

# %% [markdown]
# It looks great.This red curve is the actual value and this yellow curve are the predicted values both are pretty much close to each other.
# # Therefore the model has been successful in capturing the trend
